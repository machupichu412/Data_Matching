# %%
import pandas as pd

# %%
port_map = pd.read_excel('updated_port_map_9th_floor.xlsx', sheet_name='Sheet1')
port_map.head()
# Out:
#    Element ID Building Name    Level Serving IDF Room Room Number  \
# 0     4494245      U MI CIT  LEVEL 9       IDF 9-122C      9-214F
# 1     4494151      U MI CIT  LEVEL 9       IDF 9-122C      9-214F
# 2     4481309      U MI CIT  LEVEL 9       IDF 9-438C      9-402A
# 3    10854613      U MI CIT  LEVEL 9       IDF 9-122C      9-310A
# 4    10859261      U MI CIT  LEVEL 9       IDF 9-438C      9-320A
#
#          Room Name  Faceplate Position Faceplate/Jack # Outlet Config  \
# 0            ADMIN                   1        9-214F-01             3
# 1            ADMIN                   2        9-214F-03             3
# 2            ADMIN                   1        9-402A-01             3
# 3  ALC ARREST CART                   1        9-310A-01             3
# 4  ALC ARREST CART                   1        9-320A-01             3
#
#   Data Switch Port  A  ... Port D \nPatch Cable Color Port D  \
# 0         R3/SW1/6/37  ...    NaN                        NaN
# ...

# %%
phones = pd.read_excel('Pavilion Phone Programming Sheet DRoth Edits 5.12.25.xlsx', sheet_name='Main Sheet')
phones.head()
# Out:
#   Box / Port #\n Activation Phase  Activation Phase Date       First Name  \
# 0            NaN               NaN                   NaN  UNIV PATIENT RM
# 1            NaN               NaN                   NaN  UNIV PATIENT RM
# 2            NaN               NaN                   NaN  UNIV PATIENT RM
# 3            NaN               NaN                   NaN   NURSES STATION
# 4            NaN               NaN                   NaN   NURSES STATION
#
#    Last Name  Uniqname\n             Department   WorkGroup  \
# 0        NaN         NaN  PAVILION CORE TEAM_NRS        NaN
# 1        NaN         NaN  PAVILION CORE TEAM_NRS        NaN
# 2        NaN         NaN  PAVILION CORE TEAM_NRS        NaN
# 3        NaN         NaN          NURSES STATION        NaN
# 4        NaN         NaN          NURSES STATION        NaN
#
#    PC Term ID\n(if deploying Jabber) BLDG\n  ... Voicemail\nYes/No  \
# 0                                NaN    PAV  ...                No
# ...

# %%
phones.columns
# Out:
# Index(['Box / Port #\n', 'Activation Phase ', 'Activation Phase Date',
#        'First Name', 'Last Name', 'Uniqname\n', 'Department ', 'WorkGroup',
#        'PC Term ID\n(if deploying Jabber)', 'BLDG\n', 'Unit Rm #', 'FLOOR',
#        'Room #', 'Faceplate/Jack #', 'Patch Panel Port A',
#        '(Marcia's)Face Plate Position', 'Outlet Configuration', 'Port A',
#        'Port B', 'Jack # B', 'Patch Panel Port B', 'Port C',
#        'Patch Panel Port C', 'Port D', 'Port E', 'Port F',
#        'BDF Ca/Pr (if analog)', 'IDF Ca/Pr (if analog)', 'Serving IDF',
#        'Call Manager Programming', '\nDirectory Number\n', 'Telephone Number',
#        'MAC Address\n', 'Set Type', 'Device Description', 'DN Display\n',
#        'CSS', 'Red Phones', 'Patient Phone', 'Device Pool',
#        'Voice Gateway Name', 'Voice Gateway Port', 'Voicemail\nYes/No',
#        'Voicemail in Email\nYes/No',
#        'Forward No Answer/Busy\n(if other than Voicemail)',
# ...

# %%
phones[['Patch Panel Port A', 'Patch Panel Port B', 'Patch Panel Port C']].dropna(how='all')
# Out:
#      Patch Panel Port A Patch Panel Port B Patch Panel Port C
# 357             R2-C-25            R2-C-26            R2-C-27
# 358             R2-C-28            R2-C-29            R2-C-30
# 361             R2-C-13            R2-C-14            R2-C-15
# 362             R2-C-18            R1-E-42                NaN
# 363             R2-C-44            R2-C-45            R2-C-46
# ...                 ...                ...                ...
# 1177            R2-C-46                NaN                NaN
# 1179            R3-H-31            R3-H-32            R3-H-33
# 1180            R2-H-14            R2-H-15            R2-H-16
# 1183            R3-G-32            R3-G-33            R3-G-33
# 1184            R3-H-10            R3-H-11            R3-H-12
#
# [232 rows x 3 columns]

# %%
# TODO match up faceplate, replace each port column in port_map with corresponding label from phones
